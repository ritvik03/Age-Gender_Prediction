# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %% [markdown]
# Just detects face and eyes using Haarcascade

# %%
# !python3 "/content/drive/My Drive/Colab Notebooks/age-gender predict/face_eye_detect.py"  "/content/drive/My Drive/Colab Notebooks/age-gender predict/group.jpg" "/content/drive/My Drive/Colab Notebooks/age-gender predict/"

# %% [markdown]
# Prediction of age and gender from pre-trained models in caffe framework (NOT good results)(haarcascade must be trained for beard)

# %%
# !python3 "/content/drive/My Drive/Colab Notebooks/age-gender predict/age-gender-predict.py"  "/content/drive/My Drive/Colab Notebooks/age-gender predict/four.jpg" "/content/drive/My Drive/Colab Notebooks/age-gender predict/"
# Out:
# Found 4 faces
# Gender : Male
# Age Range: (38, 43)
# Gender : Female
# Age Range: (0, 2)
# Gender : Female
# Age Range: (25, 32)
# Gender : Female
# Age Range: (8, 12)
# Predictions Saved

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/age-gender predict/"
